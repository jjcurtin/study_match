# %% [markdown]
# # Make All Tables for Main Manuscript
#
# Gaylen Fronk
# July 11, 2024

# %%
# packages for script
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# ℹ SHA-1 hash of file is "c045eee2655a18dc85e715b78182f176327358a7"

# %%
# handle conflicts
options(conflicts.policy = "depends.ok")

# %%
# absolute paths
switch (Sys.info()[['sysname']],
        # PC paths
        Windows = {
          path_data <- str_c("P:/studydata/match/processed_data/")
          path_models <- str_c("P:/studydata/match/models/pp_hybrid_wk4_outcome")},
        
        # IOS paths
        Darwin = {
          path_data <- str_c("/Volumes/private/studydata/match/processed_data/")
          path_models <- str_c("/Volumes/private/studydata/match/models/pp_hybrid_wk4_outcome")},
        
        # Linux paths
        Linux = {
          path_data <- str_c("~/mnt/private/studydata/match/processed_data/")
          path_models <- str_c("~/mnt/private/studydata/match/models/pp_hybrid_wk4_outcome")}
)

# %%
# chunk defaults

options(tibble.width = Inf)
options(tibble.print_max = Inf)

# %% [markdown]
# ## Tables 1, 2, & 3 (Features & Sample Characteristics)

# %%
d <- read_csv(file.path(path_data, "match_cln.csv"),
              show_col_types = FALSE)

# %% [markdown]
# ### Table 1: Feature Categories
#
# Set up data

# %%
dt3 <- d |> select(-contains("outcome"), -subid)

# %% [markdown]
# Build table

# %%
t1_feat_misc <- tibble(
  feat_cat = NA_character_,
  feat_name = c("Treatment", "Incarcerated", "Works Third Shift"),
  type = c("Categorical (unordered)", "Categorical (unordered)", "Categorical (unordered)"),
  n_feat = c(1, 1, 1)
) |> 
  add_row(feat_cat = "Miscellaneous",
  feat_name = NA_character_,
  type = c(),
  n_feat = NA_real_,
  .before = 1)

t1_feat_psych_sud <- tibble(
  feat_cat = NA_character_,
  feat_name = c("Frequency of Drinking Alcohol", 
                "Quantity of Alcohol", 
                "Binge Drinking", 
                "Short Inventory of Problems-2 (Revised) [@kilukShortInventoryProblems2013]", 
                "Life Satisfaction", 
                "Life Enjoyment", 
                "Psychological Disorder Diagnoses", 
                "Positive and Negative Affect Schedule [@crawfordPositiveNegativeAffect2004a]", 
                "Snaith-Hamilton Pleasure Scale [@snaithScaleAssessmentHedonic1995a]", 
                "Anxiety Sensitivity Index-3 [@taylorRobustDimensionsAnxiety2007a]", 
                "Distress Tolerance Scale [@simonsDistressToleranceScale2005a]", 
                "Patient History Questionnaire-9 [@kroenkePHQ9ValidityBrief2001a]"),
  type = c("Categorical (ordered)", "Categorical (ordered)", "Categorical (ordered)", "Categorical (ordered)", "Categorical (ordered)", "Categorical (ordered)", "Categorical (unordered)", "Categorical (ordered)", "Categorical (ordered)", "Categorical (ordered)", "Categorical (ordered)", "Categorical (ordered)"),
  n_feat = c(1, 1, 1, 15, 1, 1, 7, 6, 14, 18, 15, 9)
) |> 
  add_row(feat_cat = "Mental Health & Psychological Traits",
  feat_name = NA_character_,
  type = c(),
  n_feat = NA_real_,
  .before = 1)

t1_feat_smoking <- tibble(
  feat_cat = NA_character_,
  feat_name = c("Baseline Carbon Monoxide", 
                "Carbon Monoxide Exposure", 
                "Age of 1st Cigarette", 
                "Age Became Daily Smoker", 
                "Years Smoking", 
                "Cigarettes Per Day (Heaviest)", 
                "Use of Other Tobacco Products", 
                "Number of Previous Quit Attempts", 
                "Last Recent Quit Attempt", 
                "Longest Quit Attempt", 
                "Previous Quit Methods Used", 
                "Cigarettes Per Day (Current)", 
                "Motivation to Quit", 
                "Self-Efficacy for Quitting in Next 30 Days", 
                "Confidence to Quit", 
                "Importance to Quit", 
                "DSM5 Tobacco Use Disorder [@americanpsychiatricassociationDiagnosticStatisticalManual2013c]", 
                "Fagerstrom Test of Nicotine Dependence [@heathertonFagerstromTestNicotine1991]", 
                "Wisconsin Inventory of Smoking Dependence Motives-37 [@smithDevelopmentBriefWisconsin2010]", 
                "Smoke Menthol Cigarettes", 
                "Wisconsin Smoking Withdrawal Scale-2 [@smithRevisionWisconsinSmoking2021]"),
  type = c("Numeric", "Categorical (unordered)", "Numeric", "Numeric", "Numeric", "Numeric", "Categorical (unordered)", "Numeric", "Categorical (ordered)", "Categorical (ordered)", "Categorical (unordered)", "Numeric", "Categorical (ordered)", "Categorical (ordered)", "Categorical (ordered)", "Categorical (ordered)", "Categorical (unordered)", "Categorical (unordered); Categorical (ordered)", "Categorical (ordered)", "Categorical (unordered)", "Categorical (ordered)"),
  n_feat = c(1, 1, 1, 1, 1, 1, 5, 1, 1, 1, 6, 1, 1, 1, 1, 1, 13, 6, 37, 1, 38)
) |> 
  add_row(feat_cat = "Smoking Use & History",
  feat_name = NA_character_,
  type = c(),
  n_feat = NA_real_,
  .before = 1)

t1_feat_medical <- tibble(
  feat_cat = NA_character_,
  feat_name = c("Diabetes Diagnosis", 
                "Multidimensional Fatigue Inventory [@smetsMultidimensionalFatigueInventory1995]", 
                "Berlin Sleep Questionnaire [@netzerUsingBerlinQuestionnaire1999]", 
                "Body Mass Index", 
                "Health-related Quality of Life Scale [@taylorMeasuringHealthyDays2000]", 
                "Healthy Days Symptoms Module [@moriartyCDCStudiesCommunity1996]"),
  type = c("Categorical (unordered)", "Categorical (ordered)", "Categorical (ordered), Categorical (unordered)", "Numeric", "Categorical (ordered), Numeric", "Numeric"),
  n_feat = c(1, 20, 3, 1, 4, 5)
) |> 
  add_row(feat_cat = "Medical & Physical Health",
  feat_name = NA_character_,
  type = c(),
  n_feat = NA_real_,
  .before = 1)

t1_feat_social_environ <- tibble(
  feat_cat = NA_character_,
  feat_name = c("Spouse Smokes", 
                "Live with Another Smoker", 
                "People Close to You Who Smoke", 
                "Ban on Smoking at Home", 
                "Ban on Smoking at Work", 
                "Time Around Other Smokers"),
  type = c("Categorical (unordered)", "Categorical (unordered)", "Categorical (unordered)", "Categorical (unordered)", "Categorical (unordered)", "Categorical (ordered)"),
  n_feat = c(1, 1, 5, 1, 1, 2)
) |> 
  add_row(feat_cat = "Social & Environmental Characteristics",
  feat_name = NA_character_,
  type = c(),
  n_feat = NA_real_,
  .before = 1)

t1_feat_demo <- tibble(
  feat_cat = NA_character_,
  feat_name = c("Gender", "Age", "Race", "Marital Status", "Income", "Ethnicity", "Employment"),
  type = c("Categorical (unordered)", "Numeric", "Categorical (unordered)", "Categorical (unordered)", "Categorical (ordered)", "Categorical (unordered)", "Categorical (unordered)"),
  n_feat = c(1, 1, 1, 1, 1, 1, 1)
) |> 
  add_row(feat_cat = "Demographic Characteristics",
  feat_name = NA_character_,
  type = c(),
  n_feat = NA_real_,
  .before = 1)

t1_feat <- bind_rows(t1_feat_demo, t1_feat_smoking) |> 
  bind_rows(t1_feat_social_environ) |> 
  bind_rows(t1_feat_psych_sud) |> 
  bind_rows(t1_feat_medical) |> 
  bind_rows(t1_feat_misc) |> 
  rename(Category = feat_cat,
         `Feature Name` = feat_name,
         Type = type,
         `Number of Items` = n_feat)

# %% [markdown]
# Table 1

# %%
t1_feat |>
  mutate(across(where(is.numeric), as.character)) |>
  mutate(across(everything(), ~replace_na(., "")))  |>
  knitr::kable()
# Out:
#   ----------------------------------------------------------------------------------------------------------------
#   Category          Feature Name                                                        Type              Number
#                                                                                                           of Items
#   ----------------- ------------------------------------------------------------------- ----------------- --------
#   Demographic
#   Characteristics
#
#                     Gender                                                              Categorical       1
#                                                                                         (unordered)
#
#                     Age                                                                 Numeric           1
#
#                     Race                                                                Categorical       1
#                                                                                         (unordered)
#
#                     Marital Status                                                      Categorical       1
#                                                                                         (unordered)
#
#                     Income                                                              Categorical       1
#                                                                                         (ordered)
#
#                     Ethnicity                                                           Categorical       1
#                                                                                         (unordered)
#
#                     Employment                                                          Categorical       1
#                                                                                         (unordered)
#
#   Smoking Use &
#   History
#
#                     Baseline Carbon Monoxide                                            Numeric           1
#
#                     Carbon Monoxide Exposure                                            Categorical       1
#                                                                                         (unordered)
#
#                     Age of 1st Cigarette                                                Numeric           1
#
#                     Age Became Daily Smoker                                             Numeric           1
#
#                     Years Smoking                                                       Numeric           1
#
#                     Cigarettes Per Day (Heaviest)                                       Numeric           1
#
#                     Use of Other Tobacco Products                                       Categorical       5
#                                                                                         (unordered)
#
#                     Number of Previous Quit Attempts                                    Numeric           1
#
#                     Last Recent Quit Attempt                                            Categorical       1
#                                                                                         (ordered)
#
#                     Longest Quit Attempt                                                Categorical       1
#                                                                                         (ordered)
#
#                     Previous Quit Methods Used                                          Categorical       6
#                                                                                         (unordered)
#
#                     Cigarettes Per Day (Current)                                        Numeric           1
#
#                     Motivation to Quit                                                  Categorical       1
#                                                                                         (ordered)
#
#                     Self-Efficacy for Quitting in Next 30 Days                          Categorical       1
#                                                                                         (ordered)
#
#                     Confidence to Quit                                                  Categorical       1
#                                                                                         (ordered)
#
#                     Importance to Quit                                                  Categorical       1
#                                                                                         (ordered)
#
#                     DSM5 Tobacco Use Disorder                                           Categorical       13
#                     [@americanpsychiatricassociationDiagnosticStatisticalManual2013c]   (unordered)
#
#                     Fagerstrom Test of Nicotine Dependence                              Categorical       6
#                     [@heathertonFagerstromTestNicotine1991]                             (unordered);
#                                                                                         Categorical
#                                                                                         (ordered)
#
#                     Wisconsin Inventory of Smoking Dependence Motives-37                Categorical       37
#                     [@smithDevelopmentBriefWisconsin2010]                               (ordered)
#
#                     Smoke Menthol Cigarettes                                            Categorical       1
#                                                                                         (unordered)
#
#                     Wisconsin Smoking Withdrawal Scale-2                                Categorical       38
#                     [@smithRevisionWisconsinSmoking2021]                                (ordered)
#
#   Social &
#   Environmental
#   Characteristics
#
#                     Spouse Smokes                                                       Categorical       1
#                                                                                         (unordered)
#
#                     Live with Another Smoker                                            Categorical       1
#                                                                                         (unordered)
#
#                     People Close to You Who Smoke                                       Categorical       5
#                                                                                         (unordered)
#
#                     Ban on Smoking at Home                                              Categorical       1
#                                                                                         (unordered)
#
#                     Ban on Smoking at Work                                              Categorical       1
#                                                                                         (unordered)
#
#                     Time Around Other Smokers                                           Categorical       2
#                                                                                         (ordered)
#
#   Mental Health &
#   Psychological
#   Traits
#
#                     Frequency of Drinking Alcohol                                       Categorical       1
#                                                                                         (ordered)
#
#                     Quantity of Alcohol                                                 Categorical       1
#                                                                                         (ordered)
#
#                     Binge Drinking                                                      Categorical       1
#                                                                                         (ordered)
#
#                     Short Inventory of Problems-2 (Revised)                             Categorical       15
#                     [@kilukShortInventoryProblems2013]                                  (ordered)
#
#                     Life Satisfaction                                                   Categorical       1
#                                                                                         (ordered)
#
#                     Life Enjoyment                                                      Categorical       1
#                                                                                         (ordered)
#
#                     Psychological Disorder Diagnoses                                    Categorical       7
#                                                                                         (unordered)
#
#                     Positive and Negative Affect Schedule                               Categorical       6
#                     [@crawfordPositiveNegativeAffect2004a]                              (ordered)
#
#                     Snaith-Hamilton Pleasure Scale [@snaithScaleAssessmentHedonic1995a] Categorical       14
#                                                                                         (ordered)
#
#                     Anxiety Sensitivity Index-3 [@taylorRobustDimensionsAnxiety2007a]   Categorical       18
#                                                                                         (ordered)
#
#                     Distress Tolerance Scale [@simonsDistressToleranceScale2005a]       Categorical       15
#                                                                                         (ordered)
#
#                     Patient History Questionnaire-9 [@kroenkePHQ9ValidityBrief2001a]    Categorical       9
#                                                                                         (ordered)
#
#   Medical &
#   Physical Health
#
#                     Diabetes Diagnosis                                                  Categorical       1
#                                                                                         (unordered)
#
#                     Multidimensional Fatigue Inventory                                  Categorical       20
#                     [@smetsMultidimensionalFatigueInventory1995]                        (ordered)
#
#                     Berlin Sleep Questionnaire [@netzerUsingBerlinQuestionnaire1999]    Categorical       3
#                                                                                         (ordered),
#                                                                                         Categorical
#                                                                                         (unordered)
#
#                     Body Mass Index                                                     Numeric           1
#
#                     Health-related Quality of Life Scale                                Categorical       4
#                     [@taylorMeasuringHealthyDays2000]                                   (ordered),
#                                                                                         Numeric
#
#                     Healthy Days Symptoms Module [@moriartyCDCStudiesCommunity1996]     Numeric           5
#
#   Miscellaneous
#
#                     Treatment                                                           Categorical       1
#                                                                                         (unordered)
#
#                     Incarcerated                                                        Categorical       1
#                                                                                         (unordered)
#
#                     Works Third Shift                                                   Categorical       1
#                                                                                         (unordered)
#   ----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Table 1, formatted for Typst/PDF output

# %%
t1_feat_demo |>
  mutate(feat_cat = " ") |>
  rename(`Demographic Characteristics` = feat_cat,
         `Feature Name` = feat_name,
         Type = type,
         `# Items` = n_feat) |>
tail(-1) |>
  knitr::kable(align = "lllc")
# Out:
#   -------------------------------------------------------------------------
#   Demographic                Feature Name   Type                   \# Items
#   Characteristics
#   -------------------------- -------------- ---------------------- --------
#                              Gender         Categorical               1
#                                             (unordered)
#
#                              Age            Numeric                   1
#
#                              Race           Categorical               1
#                                             (unordered)
#
#                              Marital Status Categorical               1
#                                             (unordered)
#
#                              Income         Categorical (ordered)     1
#
#                              Ethnicity      Categorical               1
#                                             (unordered)
#
#                              Employment     Categorical               1
#                                             (unordered)
#   -------------------------------------------------------------------------

# %%
t1_feat_smoking |>
  mutate(feat_cat = " ") |>
  rename(`Smoking Use/History` = feat_cat,
         `Feature Name` = feat_name,
         Type = type,
         `# Items` = n_feat) |>
tail(-1) |>
  knitr::kable(align = "lllc")
# Out:
#   -------------------------------------------------------------------------------------------------------------
#   Smoking       Feature Name                                                        Type                  \#
#   Use/History                                                                                            Items
#   ------------- ------------------------------------------------------------------- ------------------- -------
#                 Baseline Carbon Monoxide                                            Numeric                1
#
#                 Carbon Monoxide Exposure                                            Categorical            1
#                                                                                     (unordered)
#
#                 Age of 1st Cigarette                                                Numeric                1
#
#                 Age Became Daily Smoker                                             Numeric                1
#
#                 Years Smoking                                                       Numeric                1
#
#                 Cigarettes Per Day (Heaviest)                                       Numeric                1
#
#                 Use of Other Tobacco Products                                       Categorical            5
#                                                                                     (unordered)
#
#                 Number of Previous Quit Attempts                                    Numeric                1
#
#                 Last Recent Quit Attempt                                            Categorical            1
#                                                                                     (ordered)
#
#                 Longest Quit Attempt                                                Categorical            1
#                                                                                     (ordered)
#
#                 Previous Quit Methods Used                                          Categorical            6
#                                                                                     (unordered)
#
#                 Cigarettes Per Day (Current)                                        Numeric                1
#
#                 Motivation to Quit                                                  Categorical            1
#                                                                                     (ordered)
#
#                 Self-Efficacy for Quitting in Next 30 Days                          Categorical            1
#                                                                                     (ordered)
#
#                 Confidence to Quit                                                  Categorical            1
#                                                                                     (ordered)
#
#                 Importance to Quit                                                  Categorical            1
#                                                                                     (ordered)
#
#                 DSM5 Tobacco Use Disorder                                           Categorical           13
#                 [@americanpsychiatricassociationDiagnosticStatisticalManual2013c]   (unordered)
#
#                 Fagerstrom Test of Nicotine Dependence                              Categorical            6
#                 [@heathertonFagerstromTestNicotine1991]                             (unordered);
#                                                                                     Categorical
#                                                                                     (ordered)
#
#                 Wisconsin Inventory of Smoking Dependence Motives-37                Categorical           37
#                 [@smithDevelopmentBriefWisconsin2010]                               (ordered)
#
#                 Smoke Menthol Cigarettes                                            Categorical            1
#                                                                                     (unordered)
#
#                 Wisconsin Smoking Withdrawal Scale-2                                Categorical           38
#                 [@smithRevisionWisconsinSmoking2021]                                (ordered)
#   -------------------------------------------------------------------------------------------------------------

# %%
t1_feat_social_environ |>
  mutate(feat_cat = " ") |>
  rename(`Social & Environmental Characteristics` = feat_cat,
         `Feature Name` = feat_name,
         Type = type,
         `# Items` = n_feat) |>
tail(-1) |>
  knitr::kable(align = "lllc")
# Out:
#   -------------------------------------------------------------------------
#   Social & Environmental      Feature Name         Type               \#
#   Characteristics                                                    Items
#   --------------------------- -------------------- ---------------- -------
#                               Spouse Smokes        Categorical         1
#                                                    (unordered)
#
#                               Live with Another    Categorical         1
#                               Smoker               (unordered)
#
#                               People Close to You  Categorical         5
#                               Who Smoke            (unordered)
#
#                               Ban on Smoking at    Categorical         1
#                               Home                 (unordered)
#
#                               Ban on Smoking at    Categorical         1
#                               Work                 (unordered)
#
#                               Time Around Other    Categorical         2
#                               Smokers              (ordered)
#   -------------------------------------------------------------------------
#   --------------------------------------------------------------------------------
#   Mental Health &   Feature Name                             Type            \#
#   Psychological                                                             Items
#   Traits
#   ----------------- ---------------------------------------- ------------- -------
#                     Frequency of Drinking Alcohol            Categorical      1
#                                                              (ordered)
#
#                     Quantity of Alcohol                      Categorical      1
#                                                              (ordered)
#
#                     Binge Drinking                           Categorical      1
#                                                              (ordered)
#
#                     Short Inventory of Problems-2 (Revised)  Categorical     15
#                     [@kilukShortInventoryProblems2013]       (ordered)
#
#                     Life Satisfaction                        Categorical      1
#                                                              (ordered)
#
#                     Life Enjoyment                           Categorical      1
#                                                              (ordered)
#
#                     Psychological Disorder Diagnoses         Categorical      7
#                                                              (unordered)
#
#                     Positive and Negative Affect Schedule    Categorical      6
#                     [@crawfordPositiveNegativeAffect2004a]   (ordered)
#
#                     Snaith-Hamilton Pleasure Scale           Categorical     14
#                     [@snaithScaleAssessmentHedonic1995a]     (ordered)
#
#                     Anxiety Sensitivity Index-3              Categorical     18
#                     [@taylorRobustDimensionsAnxiety2007a]    (ordered)
#
#                     Distress Tolerance Scale                 Categorical     15
#                     [@simonsDistressToleranceScale2005a]     (ordered)
#
#                     Patient History Questionnaire-9          Categorical      9
#                     [@kroenkePHQ9ValidityBrief2001a]         (ordered)
#   --------------------------------------------------------------------------------

# %%
t1_feat_medical |>
  mutate(feat_cat = " ") |>
  rename(`Medical & Physical Health` = feat_cat,
         `Feature Name` = feat_name,
         Type = type,
         `# Items` = n_feat) |>
tail(-1) |>
  knitr::kable(align = "lllc")
# Out:
#   ---------------------------------------------------------------------------------------
#   Medical &   Feature Name                                   Type                   \#
#   Physical                                                                         Items
#   Health
#   ----------- ---------------------------------------------- -------------------- -------
#               Diabetes Diagnosis                             Categorical             1
#                                                              (unordered)
#
#               Multidimensional Fatigue Inventory             Categorical            20
#               [@smetsMultidimensionalFatigueInventory1995]   (ordered)
#
#               Berlin Sleep Questionnaire                     Categorical             3
#               [@netzerUsingBerlinQuestionnaire1999]          (ordered),
#                                                              Categorical
#                                                              (unordered)
#
#               Body Mass Index                                Numeric                 1
#
#               Health-related Quality of Life Scale           Categorical             4
#               [@taylorMeasuringHealthyDays2000]              (ordered), Numeric
#
#               Healthy Days Symptoms Module                   Numeric                 5
#               [@moriartyCDCStudiesCommunity1996]
#   ---------------------------------------------------------------------------------------
#   -------------------------------------------------------------------------
#   Miscellaneous Features Feature Name      Type                    \# Items
#   ---------------------- ----------------- ----------------------- --------
#                          Treatment         Categorical (unordered)    1
#
#                          Incarcerated      Categorical (unordered)    1
#
#                          Works Third Shift Categorical (unordered)    1
#   -------------------------------------------------------------------------

# %% [markdown]
# ### Table 2: Demographic Characteristics
#
# Select down data

# %%
dt2 <- d |> 
  select(employment, ends_with("_ehr"), income_order) |> 
  select(-bmi_ehr, -diabetic_ehr) |> 
  glimpse()
# Out:
# Rows: 1,086
# Columns: 7
# $ employment         <chr> "unemployed", "employed_full_time", "employed_full_…
# $ gender_ehr         <chr> "female", "female", "female", "female", "female", "…
# $ age_ehr            <dbl> 49, 38, 51, 55, 65, 50, 48, 47, 45, 47, 52, 70, 48,…
# $ race_ehr           <chr> "white", "white", "white", "white", "white", "white…
# $ marital_status_ehr <chr> "divorced", "married", "divorced", "married", "marr…
# $ ethnicity_ehr      <chr> "non_hispanic", "non_hispanic", "non_hispanic", "no…
# $ income_order       <chr> "01_less_than_10000", "07_more_than_75000", "06_btw…

# %% [markdown]
# Build table

# %%
tab_race <- dt2 |> 
  tab(race_ehr) |> 
  mutate(race_ehr = case_match(
    race_ehr,
    "asian" ~ "   Asian",
    "black_african_american" ~ "   Black/African American",
    "multiracial" ~ "   Multiracial",
    "native_american_alaska_native" ~ "   Native American/Alaska Native",
    "other" ~ "   Other",
    "white" ~ "   White"
  )) |> 
  rename(var_name = race_ehr) |> 
  mutate(n_prop = str_c(n, " (", round((prop * 100), digits = 2), "%)")) |> 
  select(var_name, n_prop) |> 
  add_row(var_name = "Race",
          n_prop = "",
          .before = 1)

tab_ethnicity <- dt2 |> 
  tab(ethnicity_ehr) |> 
  mutate(ethnicity_ehr = case_match(
    ethnicity_ehr,
    "hispanic_latinx" ~ "   Hispanic or Latino/a",
    "non_hispanic" ~ "   Non-Hispanic"
  )) |> 
  rename(var_name = ethnicity_ehr) |> 
  mutate(n_prop = str_c(n, " (", round((prop * 100), digits = 2), "%)")) |> 
  select(var_name, n_prop) |> 
  add_row(var_name = "Ethnicity",
          n_prop = "",
          .before = 1)

tab_gender <- dt2 |> 
  tab(gender_ehr) |> 
  mutate(gender_ehr = case_match(
    gender_ehr,
    "female" ~ "   Female",
    "male" ~ "   Male"
  )) |> 
  rename(var_name = gender_ehr) |> 
  mutate(n_prop = str_c(n, " (", round((prop * 100), digits = 2), "%)")) |> 
  select(var_name, n_prop) |> 
  add_row(var_name = "Gender",
          n_prop = "",
          .before = 1)

tab_employment <- dt2 |> 
  tab(employment) |> 
  mutate(employment = case_match(
    employment,
    "employed_full_time" ~ "   Employed (full-time)",
    "employed_part_time" ~ "   Employed (part-time)",
    "unemployed" ~ "   Unemployed"
  )) |> 
  rename(var_name = employment) |> 
  mutate(n_prop = str_c(n, " (", round((prop * 100), digits = 2), "%)")) |> 
  select(var_name, n_prop) |> 
  add_row(var_name = "Employment",
          n_prop = "",
          .before = 1)

tab_marital <- dt2 |> 
  tab(marital_status_ehr) |> 
  mutate(marital_status_ehr = case_match(
    marital_status_ehr,
    "divorced" ~ "   Divorced",
    "live_with_domestic_partner" ~ "   Living with a domestic partner",
    "married" ~ "   Married",
    "separated" ~ "   Separated",
    "widowed" ~ "   Widowed",
    "never_married" ~ "   Never married",
    NA ~ "   Did not respond"
  )) |> 
  rename(var_name = marital_status_ehr) |> 
  mutate(n_prop = str_c(n, " (", round((prop * 100), digits = 2), "%)")) |> 
  select(var_name, n_prop) |> 
  add_row(var_name = "Marital Status",
          n_prop = "",
          .before = 1)

tab_income <- dt2 |> 
  tab(income_order) |> 
  mutate(income_order = case_match(
    income_order,
    "01_less_than_10000" ~ "   < $10,000",
    "02_btwn_10000_19999" ~ "   $10,000 - $19,999",
    "03_btwn_20000_24999" ~ "   $20,000 - $24,999",
    "04_btwn_25000_34999" ~ "   $25,000 - $34,999",
    "05_btwn_35000_49999" ~ "   $35,000 - $49,999",
    "06_btwn_50000_74999" ~ "   $50,000 - $74,999",
    "07_more_than_75000" ~ "   $75,000+",
    NA ~ "   Did not respond"
  )) |> 
  rename(var_name = income_order) |> 
  mutate(n_prop = str_c(n, " (", round((prop * 100), digits = 2), "%)")) |> 
  select(var_name, n_prop) |> 
  add_row(var_name = "Income",
          n_prop = "",
          .before = 1)

tab_age <- tibble(
  var_name = "Age",
  n_prop = "",
  `Mean (SD)` = str_c(round(mean(dt2$age_ehr), digits = 2),
                      " (", round(sd(dt2$age_ehr), digits = 2), ")")
)

t2_demo <- bind_rows(tab_gender, tab_race) |> 
  bind_rows(tab_ethnicity) |> 
  bind_rows(tab_marital) |> 
  bind_rows(tab_employment) |> 
  bind_rows(tab_income) |> 
  mutate(`Mean (SD)` = "") |> 
  add_row(tab_age, .before = 1) |> 
  rename(Characteristic = var_name,
         `N (%)` = n_prop)

# %% [markdown]
# Table 2

# %%
t2_demo |>
  knitr::kable()
# Out:
#   Characteristic                   N (%)           Mean (SD)
#   -------------------------------- --------------- --------------
#   Age                                              48.13 (11.6)
#   Gender
#   Female                           566 (52.12%)
#   Male                             520 (47.88%)
#   Race
#   Asian                            3 (0.28%)
#   Black/African American           309 (28.45%)
#   Multiracial                      22 (2.03%)
#   Native American/Alaska Native    6 (0.55%)
#   Other                            18 (1.66%)
#   White                            728 (67.03%)
#   Ethnicity
#   Hispanic or Latino/a             27 (2.49%)
#   Non-Hispanic                     1059 (97.51%)
#   Marital Status
#   Divorced                         224 (20.63%)
#   Living with a domestic partner   87 (8.01%)
#   Married                          384 (35.36%)
#   Never married                    299 (27.53%)
#   Separated                        53 (4.88%)
#   Widowed                          34 (3.13%)
#   Did not respond                  5 (0.46%)
#   Employment
#   Employed (full-time)             474 (43.65%)
#   Employed (part-time)             283 (26.06%)
#   Unemployed                       329 (30.29%)
#   Income
#   \< \$10,000                      210 (19.34%)
#   \$10,000 - \$19,999              135 (12.43%)
#   \$20,000 - \$24,999              83 (7.64%)
#   \$25,000 - \$34,999              129 (11.88%)
#   \$35,000 - \$49,999              149 (13.72%)
#   \$50,000 - \$74,999              160 (14.73%)
#   \$75,000+                        167 (15.38%)
#   Did not respond                  53 (4.88%)

# %%
t2_demo |>
  head(-9) |>
  knitr::kable()
# Out:
#   Characteristic                   N (%)           Mean (SD)
#   -------------------------------- --------------- --------------
#   Age                                              48.13 (11.6)
#   Gender
#   Female                           566 (52.12%)
#   Male                             520 (47.88%)
#   Race
#   Asian                            3 (0.28%)
#   Black/African American           309 (28.45%)
#   Multiracial                      22 (2.03%)
#   Native American/Alaska Native    6 (0.55%)
#   Other                            18 (1.66%)
#   White                            728 (67.03%)
#   Ethnicity
#   Hispanic or Latino/a             27 (2.49%)
#   Non-Hispanic                     1059 (97.51%)
#   Marital Status
#   Divorced                         224 (20.63%)
#   Living with a domestic partner   87 (8.01%)
#   Married                          384 (35.36%)
#   Never married                    299 (27.53%)
#   Separated                        53 (4.88%)
#   Widowed                          34 (3.13%)
#   Did not respond                  5 (0.46%)
#   Employment
#   Employed (full-time)             474 (43.65%)
#   Employed (part-time)             283 (26.06%)
#   Unemployed                       329 (30.29%)

# %%
t2_demo |>
  tail(9) |>
  knitr::kable()
# Out:
#   Characteristic        N (%)          Mean (SD)
#   --------------------- -------------- -----------
#   Income
#   \< \$10,000           210 (19.34%)
#   \$10,000 - \$19,999   135 (12.43%)
#   \$20,000 - \$24,999   83 (7.64%)
#   \$25,000 - \$34,999   129 (11.88%)
#   \$35,000 - \$49,999   149 (13.72%)
#   \$50,000 - \$74,999   160 (14.73%)
#   \$75,000+             167 (15.38%)
#   Did not respond       53 (4.88%)

# %% [markdown]
# ### Table 3: Smoking-related ID Characteristics
#
# Select down data

# %%
dt3 <- d |> 
  select(age_1st_cig, age_daily_smoker, years_smoke, cigs_per_day_heaviest,
         tot_quit_attempt, cigs_per_day, dsm5_total_scale, ftnd_1_item_order,
         wisdm37_total_scale, wsws_total_scale)

# %% [markdown]
# Build table

# %%
tab_ftnd_1 <- dt3 |> 
  tab(ftnd_1_item_order) |> 
  mutate(ftnd_1_item_order = case_match(
    ftnd_1_item_order,
    "03_within_5_min" ~ "   Within 5 minutes",
    "02_6_to_30_min" ~ "   6 - 30 minutes",
    "01_31_to_60_min" ~ "   31 - 60 minutes",
    "00_after_60_min" ~ "   After 60 minutes",
    NA ~ "   Did not respond"
  )) |> 
  rename(var_name = ftnd_1_item_order) |> 
  mutate(n_prop = str_c(n, " (", round((prop * 100), digits = 2), "%)")) |> 
  select(var_name, n_prop) |> 
  add_row(var_name = "Time to first cigarette upon waking",
          n_prop = "",
          .before = 1) |> 
  rename(`N (%)` = n_prop, Characteristic = var_name) |> 
  mutate(`Mean (SD)` = "")

tab3_means <- dt3 |> 
  select(-ftnd_1_item_order) |> 
  summarize(across(everything(), ~ mean(.x, na.rm = TRUE))) |> 
  pivot_longer(
    cols = everything(),
    names_to = "var_name",
    values_to = "means"
  ) |> 
  mutate(means = round(means, digits = 2))

tab3_sds <- dt3 |> 
  select(-ftnd_1_item_order) |> 
  summarize(across(everything(), ~ sd(.x, na.rm = TRUE))) |> 
  pivot_longer(
    cols = everything(),
    names_to = "var_name",
    values_to = "sds"
  ) |> 
  mutate(sds = round(sds, digits = 2))

t3_idchars <- full_join(tab3_means, tab3_sds, by = "var_name") |> 
  mutate(var_name = case_match(
    var_name,
    "age_1st_cig" ~ "Age of first cigarette",
    "age_daily_smoker" ~ "Age became daily smoker",
    "years_smoke" ~ "Years smoking",
    "cigs_per_day" ~ "Cigarettes per day (current)",
    "cigs_per_day_heaviest" ~ "Cigarettes per day (heaviest)",
    "tot_quit_attempt" ~ "Number of previous quit attempts",
    "dsm5_total_scale" ~ "Number of DSM5 tobacco use disorder symptoms",
    "wisdm37_total_scale" ~ "WISDM37 Total Score",
    "wsws_total_scale" ~ "WSWS Total Score"
  )) |> 
  mutate(`Mean (SD)` = str_c(means, " (", sds, ")"),
         `N (%)` = "") |> 
  rename(Characteristic = var_name) |> 
  select(-means, -sds) |> 
  full_join(tab_ftnd_1,
            by = join_by(Characteristic, `Mean (SD)`, `N (%)`))

# %% [markdown]
# Table 3

# %%
t3_idchars |>
  knitr::kable()
# Out:
#   -----------------------------------------------------------------------
#   Characteristic                               Mean (SD)     N (%)
#   -------------------------------------------- ------------- ------------
#   Age of first cigarette                       14.6 (3.42)
#
#   Age became daily smoker                      17.56 (4.62)
#
#   Years smoking                                28.65 (12.03)
#
#   Cigarettes per day (heaviest)                22.74 (10.67)
#
#   Number of previous quit attempts             3.91 (6.03)
#
#   Cigarettes per day (current)                 17.03 (8.31)
#
#   Number of DSM5 tobacco use disorder symptoms 4.57 (2.17)
#
#   WISDM37 Total Score                          3.99 (1.17)
#
#   WSWS Total Score                             48.82 (19.91)
#
#   Time to first cigarette upon waking
#
#   After 60 minutes                                           82 (7.55%)
#
#   31 - 60 minutes                                            157 (14.46%)
#
#   6 - 30 minutes                                             477 (43.92%)
#
#   Within 5 minutes                                           366 (33.7%)
#
#   Did not respond                                            4 (0.37%)
#   -----------------------------------------------------------------------

# %% [markdown]
# ## Tables 4, 5, & 6 (Treatment Interactions)
#
# Read in data

# %%
model_tidy <- read_csv(file.path(path_models, "model_best_tidy_v6.csv"),
                       show_col_types = FALSE) |> 
  glimpse()
# Out:
# Rows: 1,173
# Columns: 3
# $ term     <chr> "(Intercept)", "age_ehr", "co", "income_order", "age_1st_cig"…
# $ estimate <dbl> 0.749187531, 0.000000000, 0.182416896, -0.055715240, 0.000000…
# $ penalty  <dbl> 0.1140801, 0.1140801, 0.1140801, 0.1140801, 0.1140801, 0.1140…

# %% [markdown]
# Make overall starting table

# %%
retained_vars_tx <- model_tidy |> 
  mutate(estimate = estimate * -1) |> 
  filter(abs(estimate) > 0) |> 
  select(-penalty) |> 
  filter(str_detect(term, "treatment_")) |> 
  arrange(desc(abs(estimate)))

print_kbl(retained_vars_tx, digits = 4)
# Out:
# <div style="border: 1px solid #ddd; padding: 0px; overflow-y: scroll; height:500px; overflow-x: scroll; width:100%; "><table class="table table-striped table-condensed" style="margin-left: auto; margin-right: auto;">
#  <thead>
#   <tr>
#    <th style="text-align:right;position: sticky; top:0; background-color: #FFFFFF;"> term </th>
#    <th style="text-align:right;position: sticky; top:0; background-color: #FFFFFF;"> estimate </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:right;"> treatment_combo_nrt_x_live_with_smoker_live_alone_or_only_with_partner </td>
#    <td style="text-align:right;"> 0.1076 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_varenicline_x_live_with_smoker_live_alone_or_only_with_partner </td>
#    <td style="text-align:right;"> -0.0722 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_combo_nrt_x_race_ehr_black_african_american </td>
#    <td style="text-align:right;"> -0.0663 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_combo_nrt_x_wisdm37_22_item_order </td>
#    <td style="text-align:right;"> -0.0607 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_combo_nrt_x_smoke_menthol_no </td>
#    <td style="text-align:right;"> 0.0468 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_patch_x_used_cigars_never_tried </td>
#    <td style="text-align:right;"> -0.0428 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_patch_x_close_smoke_friend_no </td>
#    <td style="text-align:right;"> -0.0419 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_combo_nrt_x_dts_5_item_order </td>
#    <td style="text-align:right;"> 0.0415 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_varenicline_x_asi3_15_item_order </td>
#    <td style="text-align:right;"> 0.0381 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_patch_x_used_cigars_tried </td>
#    <td style="text-align:right;"> 0.0354 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_patch_x_close_smoke_co_worker_yes </td>
#    <td style="text-align:right;"> 0.0336 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_varenicline_x_mfi_6_item_order </td>
#    <td style="text-align:right;"> 0.0320 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_varenicline_x_income_order </td>
#    <td style="text-align:right;"> 0.0317 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_varenicline_x_spouse_smoke_no </td>
#    <td style="text-align:right;"> 0.0316 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_combo_nrt_x_wisdm37_30_item_order </td>
#    <td style="text-align:right;"> -0.0301 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_combo_nrt_x_marital_status_ehr_divorced </td>
#    <td style="text-align:right;"> -0.0293 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_combo_nrt_x_dsm5_6_item_no </td>
#    <td style="text-align:right;"> 0.0287 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_varenicline_x_close_smoke_relative_no </td>
#    <td style="text-align:right;"> -0.0287 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_varenicline_x_dsm5_3_item_yes </td>
#    <td style="text-align:right;"> 0.0275 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_varenicline_x_used_cigars_never_tried </td>
#    <td style="text-align:right;"> 0.0259 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_combo_nrt_x_asi3_2_item_order </td>
#    <td style="text-align:right;"> -0.0257 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_combo_nrt_x_race_ehr_white </td>
#    <td style="text-align:right;"> 0.0251 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_combo_nrt_x_marital_status_ehr_married </td>
#    <td style="text-align:right;"> 0.0242 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_combo_nrt_x_dsm5_10_item_yes </td>
#    <td style="text-align:right;"> -0.0235 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_patch_x_work_ban_no_smoking_allowed </td>
#    <td style="text-align:right;"> -0.0232 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_patch_x_wsws_crave_24h_item_order </td>
#    <td style="text-align:right;"> -0.0226 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_combo_nrt_x_smoke_menthol_yes </td>
#    <td style="text-align:right;"> -0.0218 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_varenicline_x_psych_depression_yes </td>
#    <td style="text-align:right;"> 0.0214 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_combo_nrt_x_wisdm37_19_item_order </td>
#    <td style="text-align:right;"> -0.0213 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_patch_x_wisdm37_26_item_order </td>
#    <td style="text-align:right;"> 0.0207 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_varenicline_x_live_with_smoker_no </td>
#    <td style="text-align:right;"> 0.0204 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_patch_x_close_smoke_friend_yes </td>
#    <td style="text-align:right;"> 0.0198 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_varenicline_x_wisdm37_32_item_order </td>
#    <td style="text-align:right;"> -0.0188 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_combo_nrt_x_mfi_13_item_order </td>
#    <td style="text-align:right;"> 0.0150 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_varenicline_x_berlin_7_order </td>
#    <td style="text-align:right;"> -0.0146 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_varenicline_x_used_cigars_tried </td>
#    <td style="text-align:right;"> -0.0144 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_varenicline_x_wisdm37_27_item_order </td>
#    <td style="text-align:right;"> -0.0135 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_varenicline_x_close_smoke_relative_yes </td>
#    <td style="text-align:right;"> 0.0124 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_combo_nrt_x_ftnd_6_item_no </td>
#    <td style="text-align:right;"> 0.0123 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_combo_nrt_x_live_with_smoker_yes </td>
#    <td style="text-align:right;"> -0.0113 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_patch_x_marital_status_ehr_never_married </td>
#    <td style="text-align:right;"> 0.0104 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_patch_x_gender_ehr_female </td>
#    <td style="text-align:right;"> -0.0103 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_varenicline_x_wsws_constipation_24h_item_order </td>
#    <td style="text-align:right;"> 0.0099 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_combo_nrt_x_life_satisfaction_order </td>
#    <td style="text-align:right;"> 0.0099 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_varenicline_x_dsm5_7_item_no </td>
#    <td style="text-align:right;"> -0.0082 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_combo_nrt_x_wsws_constipation_24h_item_order </td>
#    <td style="text-align:right;"> -0.0080 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_patch_x_ftnd_2_item_yes </td>
#    <td style="text-align:right;"> 0.0072 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_patch_x_wisdm37_16_item_order </td>
#    <td style="text-align:right;"> 0.0067 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_varenicline_x_tried_nic_gum_yes </td>
#    <td style="text-align:right;"> 0.0067 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_combo_nrt_x_used_pipe_tried </td>
#    <td style="text-align:right;"> -0.0065 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_varenicline_x_spouse_smoke_yes </td>
#    <td style="text-align:right;"> -0.0065 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;"> treatment_patch_x_race_ehr_white </td>

# %% [markdown]
# ### Table 4: Varenicline Interactions
#
# Make table

# %%
varenicline <- retained_vars_tx |> 
  filter(str_detect(term, "varenicline")) |> 
  mutate(term = str_replace(term, "treatment_varenicline_x_", "")) |> 
  arrange(desc(abs(estimate))) |> 
  mutate(direction = if_else(estimate > 0, "+", "-")) |> 
  mutate(Feature = c(
    "Lives alone or only with a partner",
    "ASI-3: Worries they will choke to death when their throat feels tight",
    "MFI: Does not think they do a lot in a day",
    "Greater income",
    "Has a spouse/partner who does not smoke",
    "No close relative who smokes",
    "DSM-5: Smoked despite relationship problems",
    "Has never tried cigars",
    "Has a depression diagnosis",
    "Does not live with another smoker",
    "WISDM-37: Endorses smoking helps them think better",
    "Berlin: Feels tired, fatigued, or not up to par",
    "Has tried cigars but has never used regularly",
    "WISDM-37: Endorses having a lot of friends or family members smoke",
    "Has a close relative who smokes",
    "WSWS-2: Bothered by constipation",
    "DSM-5: Smoked to get rid of withdrawal feelings",
    "Tried nicotine gum during previous quit attempt",
    "Has a spouse/partner who smokes",
    "Has not tried nicotine gum during a previous quit attempt",
    "WSWS-2: Bothered by feeling hopeless or discouraged",
    "WISDM-37: Endorses most of the people they spend time with are smokers",
    "Does not live with a spouse/partner",
    "Smoking only allowed in some parts of workplace"
  )) |> 
  mutate(Category = c(
    "Social/Environmental",
    "Psychological",
    "Medical",
    "Demographic",
    "Social/Environmental",
    "Social/Environmental",
    "Smoking Use/History",
    "Smoking Use/History",
    "Psychological",
    "Social/Environmental",
    "Smoking Use/History",
    "Medical",
    "Smoking Use/History",
    "Smoking Use/History",
    "Social/Environmental",
    "Smoking Use/History",
    "Smoking Use/History",
    "Smoking Use/History",
    "Social/Environmental",
    "Smoking Use/History",
    "Smoking Use/History",
    "Smoking Use/History",
    "Social/Environmental",
    "Social/Environmental"
  )) |> 
  select(Category, Feature, `Effect Direction (Varenicline)` = direction)

# %%
varenicline |> 
  knitr::kable(align = "lc")
# Out:
#   ----------------------------------------------------------------------------------
#   Category                                Feature                  Effect Direction
#                                                                    (Varenicline)
#   ---------------------- ----------------------------------------- -----------------
#   Social/Environmental      Lives alone or only with a partner     \-
#
#   Psychological           ASI-3: Worries they will choke to death  \+
#                                when their throat feels tight
#
#   Medical                 MFI: Does not think they do a lot in a   \+
#                                             day
#
#   Demographic                         Greater income               \+
#
#   Social/Environmental    Has a spouse/partner who does not smoke  \+
#
#   Social/Environmental         No close relative who smokes        \-
#
#   Smoking Use/History       DSM-5: Smoked despite relationship     \+
#                                          problems
#
#   Smoking Use/History             Has never tried cigars           \+
#
#   Psychological                 Has a depression diagnosis         \+
#
#   Social/Environmental       Does not live with another smoker     \+
#
#   Smoking Use/History      WISDM-37: Endorses smoking helps them   \-
#                                        think better
#
#   Medical                Berlin: Feels tired, fatigued, or not up  \-
#                                           to par
#
#   Smoking Use/History       Has tried cigars but has never used    \-
#                                          regularly
#
#   Smoking Use/History       WISDM-37: Endorses having a lot of     \-
#                               friends or family members smoke
#
#   Social/Environmental        Has a close relative who smokes      \+
#
#   Smoking Use/History        WSWS-2: Bothered by constipation      \+
#
#   Smoking Use/History     DSM-5: Smoked to get rid of withdrawal   \-
#                                          feelings
#
#   Smoking Use/History     Tried nicotine gum during previous quit  \+
#                                           attempt
#
#   Social/Environmental        Has a spouse/partner who smokes      \-
#
#   Smoking Use/History       Has not tried nicotine gum during a    \-
#                                    previous quit attempt
#
#   Smoking Use/History     WSWS-2: Bothered by feeling hopeless or  \-
#                                         discouraged
#
#   Smoking Use/History      WISDM-37: Endorses most of the people   \-
#                              they spend time with are smokers
#
#   Social/Environmental      Does not live with a spouse/partner    \-
#
#   Social/Environmental     Smoking only allowed in some parts of   \-
#                                          workplace
#   ----------------------------------------------------------------------------------

# %% [markdown]
# ### Table 5: Combo-NRT Interactions
#
# Make table

# %%
combo_nrt <- retained_vars_tx |> 
  filter(str_detect(term, "combo_nrt")) |> 
  mutate(term = str_replace(term, "treatment_combo_nrt_x_", "")) |> 
  arrange(desc(abs(estimate))) |> 
  mutate(direction = if_else(estimate > 0, "+", "-")) |> 
  mutate(Feature = c(
    "Lives alone or only with a partner",
    "Identifies as Black or African American",
    "WISDM-37: Endorses feeling like cigarattes are their best friends",
    "Has never smoked menthol cigarettes",
    "DTS: Disagrees that there is nothing worse than feeling distressed or upset",
    "WISDM-37: Endorses that most of their friends and acquaintances smoke",
    "Divorced",
    "DSM-5: Does not endorse withdrawal symptoms",
    "ASI-3: Worries they are going crazy when they cannot keep their mind on a task",
    "Identifies as White",
    "Married",
    "DSM-5: Has spent a lot of time obtaining, smoking, or recovering from cigarettes",
    "Currently smokes menthol cigarettes",
    "WISDM-37: Endorses weight control as a major reason they smoke",
    "MFI: Does not feel it takes a lot of effort to concentrate",
    "FTND: Does not smoke when so ill they are in bed most of the day",
    "Lives with another smoker",
    "More satisfied with their life as a whole",
    "WSWS-2: Bothered by constipation",
    "Has tried a pipe but has never used regularly",
    "Greater duration of time since most recent quit attempt",
    "DTS: Can handle feeling distressed or upset",
    "FTND: Smokes when so ill they are in bed most of the day",
    "Berlin: No sleep apnea diagnosis",
    "WSWS-2: Bothered by waking frequently during the night",
    "WSWS-2: Bothered by having urges to smoke",
    "HDSM: More days in past month feeling worried, tense, or anxious",
    "WSWS-2: Bothered by wanting to smoke",
    "DSM-5: Smoked knowing it was causing or worsening a health problem",
    "DTS: Does not find feeling distressed or upset to be unbearable",
    "Tried Zyban (bupropion) during previous attempt"
  )) |> 
  mutate(Category = c(
    "Social/Environmental",
    "Demographic",
    "Smoking Use/History",
    "Smoking Use/History",
    "Psychological",
    "Smoking Use/History",
    "Demographic",
    "Smoking Use/History",
    "Psychological",
    "Demographic",
    "Demographic",
    "Smoking Use/History",
    "Smoking Use/History",
    "Smoking Use/History",
    "Medical",
    "Smoking Use/History",
    "Social/Environmental",
    "Psychological",
    "Smoking Use/History",
    "Smoking Use/History",
    "Smoking Use/History",
    "Psychological",
    "Smoking Use/History",
    "Medical",
    "Smoking Use/History",
    "Smoking Use/History",
    "Medical",
    "Smoking Use/History",
    "Smoking Use/History",
    "Psychological",
    "Smoking Use/History"
  )) |> 
  select(Category, Feature, `Effect Direction (C-NRT)` = direction)

# %%
combo_nrt |> 
  knitr::kable(align = "lc")
# Out:
#   ----------------------------------------------------------------------------------
#   Category                                  Feature                    Effect
#                                                                        Direction
#                                                                        (C-NRT)
#   ---------------------- --------------------------------------------- -------------
#   Social/Environmental        Lives alone or only with a partner       \+
#
#   Demographic               Identifies as Black or African American    \-
#
#   Smoking Use/History     WISDM-37: Endorses feeling like cigarattes   \-
#                                     are their best friends
#
#   Smoking Use/History         Has never smoked menthol cigarettes      \+
#
#   Psychological           DTS: Disagrees that there is nothing worse   \+
#                                than feeling distressed or upset
#
#   Smoking Use/History    WISDM-37: Endorses that most of their friends \-
#                                     and acquaintances smoke
#
#   Demographic                              Divorced                    \-
#
#   Smoking Use/History     DSM-5: Does not endorse withdrawal symptoms  \+
#
#   Psychological          ASI-3: Worries they are going crazy when they \-
#                                cannot keep their mind on a task
#
#   Demographic                         Identifies as White              \+
#
#   Demographic                               Married                    \+
#
#   Smoking Use/History      DSM-5: Has spent a lot of time obtaining,   \-
#                             smoking, or recovering from cigarettes
#
#   Smoking Use/History         Currently smokes menthol cigarettes      \-
#
#   Smoking Use/History    WISDM-37: Endorses weight control as a major  \-
#                                        reason they smoke
#
#   Medical                 MFI: Does not feel it takes a lot of effort  \+
#                                         to concentrate
#
#   Smoking Use/History    FTND: Does not smoke when so ill they are in  \+
#                                       bed most of the day
#
#   Social/Environmental             Lives with another smoker           \-
#
#   Psychological            More satisfied with their life as a whole   \+
#
#   Smoking Use/History          WSWS-2: Bothered by constipation        \-
#
#   Smoking Use/History    Has tried a pipe but has never used regularly \-
#
#   Smoking Use/History     Greater duration of time since most recent   \+
#                                          quit attempt
#
#   Psychological           DTS: Can handle feeling distressed or upset  \+
#
#   Smoking Use/History    FTND: Smokes when so ill they are in bed most \-
#                                           of the day
#
#   Medical                      Berlin: No sleep apnea diagnosis        \+
#
#   Smoking Use/History    WSWS-2: Bothered by waking frequently during  \+
#                                            the night
#
#   Smoking Use/History      WSWS-2: Bothered by having urges to smoke   \-
#
#   Medical                    HDSM: More days in past month feeling     \-
#                                   worried, tense, or anxious
#
#   Smoking Use/History        WSWS-2: Bothered by wanting to smoke      \-
#
#   Smoking Use/History       DSM-5: Smoked knowing it was causing or    \+
#                                   worsening a health problem
#
#   Psychological            DTS: Does not find feeling distressed or    \+
#                                     upset to be unbearable
#
#   Smoking Use/History       Tried Zyban (bupropion) during previous    \-
#                                             attempt
#   ----------------------------------------------------------------------------------

# %% [markdown]
# ### Table 6: Patch Interactions
#
# Make table

# %%
patch <- retained_vars_tx |> 
  filter(str_detect(term, "patch")) |> 
  mutate(term = str_replace(term, "treatment_patch_x_", "")) |> 
  arrange(desc(abs(estimate))) |> 
  mutate(direction = if_else(estimate > 0, "+", "-")) |> 
  mutate(Feature = c(
    "Has never tried cigars",
    "No close friend who smokes",
    "Has tried cigars but has never used regularly",
    "Has a close co-worker who smokes",
    "No smoking allowed anywhere at their workplace",
    "WSWS-2: Bothered by craving a cigarette",
    "WISDM-37: Endorses feeling alone without their cigarettes",
    "Has a close friend who smokes",
    "Has never been married",
    "Identifies as female",
    "FTND: Finds it difficult to refrain from smoking where it is forbidden",
    "WISDM-37: Endorses feeling that cigarettes rule their life",
    "Identifies as White",
    "Does not work outside the home",
    "WSWS-2: Bothered by coughing",
    "MFI: Does not have a lot of plans",
    "Identifies as male",
    "WSWS-2: Bothered by having trouble getting cigarettes of their mind",
    "Greater total number of previous quit attempts"
  )) |> 
  mutate(Category = c(
    "Smoking Use/History",
    "Social/Environmental",
    "Smoking Use/History",
    "Social/Environmental",
    "Social/Environmental",
    "Smoking Use/History",
    "Smoking Use/History",
    "Social/Environmental",
    "Demographic",
    "Demographic",
    "Smoking Use/History",
    "Smoking Use/History",
    "Demographic",
    "Social/Environmental",
    "Smoking Use/History",
    "Medical",
    "Demographic",
    "Smoking Use/History",
    "Smoking Use/History"
  )) |> 
  select(Category, Feature, `Effect Direction (Patch)` = direction)

# %%
patch |> 
  knitr::kable(align = "lc")
# Out:
#   ----------------------------------------------------------------------------------
#   Category                                 Feature                   Effect
#                                                                      Direction
#                                                                      (Patch)
#   ---------------------- ------------------------------------------- ---------------
#   Smoking Use/History              Has never tried cigars            \-
#
#   Social/Environmental           No close friend who smokes          \-
#
#   Smoking Use/History        Has tried cigars but has never used     \+
#                                           regularly
#
#   Social/Environmental        Has a close co-worker who smokes       \+
#
#   Social/Environmental      No smoking allowed anywhere at their     \-
#                                           workplace
#
#   Smoking Use/History      WSWS-2: Bothered by craving a cigarette   \-
#
#   Smoking Use/History     WISDM-37: Endorses feeling alone without   \+
#                                       their cigarettes
#
#   Social/Environmental          Has a close friend who smokes        \+
#
#   Demographic                      Has never been married            \+
#
#   Demographic                       Identifies as female             \-
#
#   Smoking Use/History     FTND: Finds it difficult to refrain from   \+
#                                 smoking where it is forbidden
#
#   Smoking Use/History    WISDM-37: Endorses feeling that cigarettes  \+
#                                        rule their life
#
#   Demographic                        Identifies as White             \+
#
#   Social/Environmental         Does not work outside the home        \+
#
#   Smoking Use/History           WSWS-2: Bothered by coughing         \+
#
#   Medical                     MFI: Does not have a lot of plans      \+
#
#   Demographic                        Identifies as male              \+
#
#   Smoking Use/History    WSWS-2: Bothered by having trouble getting  \-
#                                   cigarettes of their mind
#
#   Smoking Use/History       Greater total number of previous quit    \+
#                                           attempts
#   ----------------------------------------------------------------------------------

# %% [markdown]
# ### Combined table

# %%
int_effects <- full_join(varenicline, combo_nrt, by = c("Category", "Feature")) |> 
  full_join(patch, by = c("Category", "Feature")) |> 
  arrange(Category, Feature) |> 
  mutate(`Effect Direction (C-NRT)` = replace_na(`Effect Direction (C-NRT)`, ""),
         `Effect Direction (Patch)` = replace_na(`Effect Direction (Patch)`, ""),
         `Effect Direction (Varenicline)` = replace_na(`Effect Direction (Varenicline)`, 
                                                       "")) |> 
  mutate(Category = "") |> 
  add_row(Category = "Demographic",
          Feature = "",
          `Effect Direction (Varenicline)` = "",
          `Effect Direction (Patch)` = "",
          `Effect Direction (C-NRT)` = "",
          .before = 1) |> 
  add_row(Category = "Medical",
          Feature = "",
          `Effect Direction (Varenicline)` = "",
          `Effect Direction (Patch)` = "",
          `Effect Direction (C-NRT)` = "",
          .after = 9) |> 
  add_row(Category = "Psychological",
          Feature = "",
          `Effect Direction (Varenicline)` = "",
          `Effect Direction (Patch)` = "",
          `Effect Direction (C-NRT)` = "",
          .after = 16) |> 
  add_row(Category = "Smoking Use/History",
          Feature = "",
          `Effect Direction (Varenicline)` = "",
          `Effect Direction (Patch)` = "",
          `Effect Direction (C-NRT)` = "",
          .after = 24) |> 
  add_row(Category = "Social/Environmental",
          Feature = "",
          `Effect Direction (Varenicline)` = "",
          `Effect Direction (Patch)` = "",
          `Effect Direction (C-NRT)` = "",
          .after = 59)

# %%
knitr::kable(int_effects,
             align = "llccc")
# Out:
#   ---------------------------------------------------------------------------------------------
#   Category               Feature                            Effect        Effect      Effect
#                                                            Direction     Direction   Direction
#                                                          (Varenicline)    (C-NRT)     (Patch)
#   ---------------------- ------------------------------ --------------- ----------- -----------
#   Demographic
#
#                          Divorced                                           \-
#
#                          Greater income                       \+
#
#                          Has never been married                                         \+
#
#                          Identifies as Black or African                     \-
#                          American
#
#                          Identifies as White                                \+          \+
#
#                          Identifies as female                                           \-
#
#                          Identifies as male                                             \+
#
#                          Married                                            \+
#
#   Medical
#
#                          Berlin: Feels tired, fatigued,       \-
#                          or not up to par
#
#                          Berlin: No sleep apnea                             \+
#                          diagnosis
#
#                          HDSM: More days in past month                      \-
#                          feeling worried, tense, or
#                          anxious
#
#                          MFI: Does not feel it takes a                      \+
#                          lot of effort to concentrate
#
#                          MFI: Does not have a lot of                                    \+
#                          plans
#
#                          MFI: Does not think they do a        \+
#                          lot in a day
#
#   Psychological
#
#                          ASI-3: Worries they are going                      \-
#                          crazy when they cannot keep
#                          their mind on a task
#
#                          ASI-3: Worries they will choke       \+
#                          to death when their throat
#                          feels tight
#
#                          DTS: Can handle feeling                            \+
#                          distressed or upset
#
#                          DTS: Disagrees that there is                       \+
#                          nothing worse than feeling
#                          distressed or upset
#
#                          DTS: Does not find feeling                         \+
#                          distressed or upset to be
#                          unbearable
#
#                          Has a depression diagnosis           \+
#
#                          More satisfied with their life                     \+
#                          as a whole
#
#   Smoking Use/History
#
#                          Currently smokes menthol                           \-
#                          cigarettes
#
#                          DSM-5: Does not endorse                            \+
#                          withdrawal symptoms
#
#                          DSM-5: Has spent a lot of time                     \-
#                          obtaining, smoking, or
#                          recovering from cigarettes
#
#                          DSM-5: Smoked despite                \+
#                          relationship problems
#
#                          DSM-5: Smoked knowing it was                       \+
#                          causing or worsening a health
#                          problem
#
#                          DSM-5: Smoked to get rid of          \-
#                          withdrawal feelings
#
#                          FTND: Does not smoke when so                       \+
#                          ill they are in bed most of
#                          the day
#
#                          FTND: Finds it difficult to                                    \+
#                          refrain from smoking where it
#                          is forbidden
#
#                          FTND: Smokes when so ill they                      \-
#                          are in bed most of the day
#
#                          Greater duration of time since                     \+
#                          most recent quit attempt
#
#                          Greater total number of                                        \+
#                          previous quit attempts
#
#                          Has never smoked menthol                           \+
#                          cigarettes
#
#                          Has never tried cigars               \+                        \-
#
#                          Has not tried nicotine gum           \-
#                          during a previous quit attempt
#
#                          Has tried a pipe but has never                     \-
#                          used regularly
#
#                          Has tried cigars but has never       \-                        \+
#                          used regularly
#
#                          Tried Zyban (bupropion) during                     \-
#                          previous attempt
#
#                          Tried nicotine gum during            \+
#                          previous quit attempt
#
#                          WISDM-37: Endorses feeling                                     \+
#                          alone without their cigarettes
#
#                          WISDM-37: Endorses feeling                         \-
#                          like cigarattes are their best
#                          friends
#
#                          WISDM-37: Endorses feeling                                     \+
#                          that cigarettes rule their
#                          life
#
#                          WISDM-37: Endorses having a          \-
#                          lot of friends or family
#                          members smoke
#
#                          WISDM-37: Endorses most of the       \-
#                          people they spend time with
#                          are smokers
#
#                          WISDM-37: Endorses smoking           \-
#                          helps them think better
#
#                          WISDM-37: Endorses that most                       \-
#                          of their friends and
#                          acquaintances smoke
#
#                          WISDM-37: Endorses weight                          \-
#                          control as a major reason they
#                          smoke
#
#                          WSWS-2: Bothered by                  \+            \-
#                          constipation
#
#                          WSWS-2: Bothered by coughing                                   \+
#
#                          WSWS-2: Bothered by craving a                                  \-
#                          cigarette
#
#                          WSWS-2: Bothered by feeling          \-
#                          hopeless or discouraged
#
#                          WSWS-2: Bothered by having                                     \-
#                          trouble getting cigarettes of
#                          their mind
#
#                          WSWS-2: Bothered by having                         \-
#                          urges to smoke
#
#                          WSWS-2: Bothered by waking                         \+
#                          frequently during the night
#
#                          WSWS-2: Bothered by wanting to                     \-
#                          smoke
#
#   Social/Environmental
#
#                          Does not live with a                 \-
#                          spouse/partner
#
#                          Does not live with another           \+
#                          smoker
#
#                          Does not work outside the home                                 \+
#
#                          Has a close co-worker who                                      \+
#                          smokes
#
#                          Has a close friend who smokes                                  \+
#
#                          Has a close relative who             \+
#                          smokes
#
#                          Has a spouse/partner who does        \+
#                          not smoke
#
#                          Has a spouse/partner who             \-
#                          smokes
#
#                          Lives alone or only with a           \-            \+
#                          partner
#
#                          Lives with another smoker                          \-
#
#                          No close friend who smokes                                     \-
#
#                          No close relative who smokes         \-
#
#                          No smoking allowed anywhere at                                 \-
#                          their workplace
#
#                          Smoking only allowed in some         \-
#                          parts of workplace
#   ---------------------------------------------------------------------------------------------
